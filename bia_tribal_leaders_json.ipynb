# %%
import json 

Feature_collection_path = r"C:\Users\jjnoz\OneDrive\Desktop\Native Lands\native_land_mapping\bia_tribal_leaders_sources\featureCollection_TribalLeadership_Directory_6093717558405135322.txt"

with open(Feature_collection_path) as f:
    data = json.load(f)
    print(json.dumps(data, indent=4))
# Out:
# {
#     "layers": [
#         {
#             "layerDefinition": {
#                 "currentVersion": 11.2,
#                 "id": 0,
#                 "name": "Tribal Leaders Directory",
#                 "type": "Feature Layer",
#                 "displayField": "tribefullname",
# ...

# %%
## Get layers/layerDefinition/templates/prototype/attributes as list of dict keys

attributes = list(data['layers'][0]['layerDefinition']['templates'][0]['prototype']['attributes'].keys())

print(attributes)
# Out:
# ['longtitude', 'Tribal_Office_Type', 'tribefullname', 'tribe', 'tribealternatename', 'tribalcomponent', 'salutation', 'firstname', 'middlename', 'lastname', 'suffix', 'aka', 'jobtitle', 'organization', 'biaregion', 'biaagency', 'physicaladdress', 'city', 'state', 'zipcode', 'phone', 'fax', 'email', 'website', 'mailingaddress', 'mailingaddresscity', 'mailingaddressstate', 'mailingaddresszipcode', 'dateelected', 'nextelection', 'directory', 'notes', 'ancsaregion', 'blmregion', 'borregion', 'fwsregion', 'lcc', 'npsregion', 'usgsregion', 'alaskasubsistenceregion', 'latitude']

# %%
import pandas as pd

df_bia_tribes = pd.read_csv("bia_tribal_leaders_sources/csv_TribalLeadership_Directory_-8807089639668789909.csv")
df_bia_tribes.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\jjnoz\AppData\Local\Temp\ipykernel_27440\981654729.py:3: SyntaxWarning: invalid escape sequence '\c'
#   df_bia_tribes = pd.read_csv("bia_tribal_leaders_sources\csv_TribalLeadership_Directory_-8807089639668789909.csv")
#    OBJECTID                       Tribe Full Name     Tribe  \
# 0     17611           Agdaagux Tribe of King Cove  Agdaagux
# 1     17612             Akiachak Native Community  Akiachak
# 2     17613                Akiak Native Community     Akiak
# 3     17614                        Alatna Village    Alatna
# 4     17615  Algaaciq Native Village (St. Mary's)  Algaaciq
#
#     Tribe Alternate Name Tribal Component Salutation First Name Middle Name  \
# 0              King Cove            Tribe        NaN       Etta           P
# 1                    NaN            Tribe        NaN      Fritz         NaN
# ...
